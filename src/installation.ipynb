# %% [markdown]
# # 터미널에서 환경 설정
#
# 다음 명령어로 파이썬 가상환경을 생성한다.

# %% [markdown]
# python -m venv .venv

# %% [markdown]
# python -m pip install ipykernel
# python -m pip install ipywidgets

# %% [markdown]
# python -m pip install --upgrade pip

# %% [markdown]
# .\.venv\Scripts\Activate.ps1

# %% [markdown]
# # 설치된 라이브러리들을 파일로 기록

# %%
# !python -m pip freeze > ../requirements.txt
