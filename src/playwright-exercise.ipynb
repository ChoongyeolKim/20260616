# %% [markdown]
# # C++ 라이브러리 설치

# %% [markdown]
# * 윈도우 파워쉘을 관리자 계정으로 열고 다음과 같이 실행시킨다.
#     * winget install Microsoft.VisualStudio.BuildTools --override "--passive --wait --add Microsoft.VisualStudio.Workload.VCTools --includeRecommended"

# %% [markdown]
# # Playwright 파이썬 Wrapper 설치

# %%
# !python -m pip install playwright
# Out:
# ...
#   Using cached playwright-1.60.0-py3-none-win_amd64.whl.metadata (3.5 kB)
# ...
#   Using cached pyee-13.0.1-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached playwright-1.60.0-py3-none-win_amd64.whl (37.9 MB)
# ...
# Using cached pyee-13.0.1-py3-none-any.whl (15 kB)
# ...
#
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    -------------------------- ------------- 2/3 [playwright]
#    ---------------------------------------- 3/3 [playwright]
#
# ...
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %% [markdown]
# # Playwright 설치
# * 다음 명령어를 실행시켰을 때 에러가 나지 않아야 Playwright 를 사용할 수 있습니다.

# %%
# !playwright install
# Out:
# ...
# |                                                                                |   0% of 181.9 MiB
# |■■■■■■■■                                                                        |  10% of 181.9 MiB
# |■■■■■■■■■■■■■■■■                                                                |  20% of 181.9 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■                                                        |  30% of 181.9 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                                |  40% of 181.9 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                        |  50% of 181.9 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                                |  60% of 181.9 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                        |  70% of 181.9 MiB
# |■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■■                |  80% of 181.9 MiB
# ...

# %% [markdown]
# # Reference
#
# [위키북스] https://wikidocs.net/231787

# %% [markdown]
# # 실행
# * Python Notebook 으로 실행을 하지 않고, VS Code 에서 터미널 창을 열어서 playwright-exercise.py 를 직접 실행시킨다.
# * python .\src\playwright-exercise.py
# * 제일 밑에 있는 조건문 (if __name__ == '__main__':) 에 asyncio.run(run_playwright()) 코드가 활성화되어 있다.
# * 나중에 해당 코드를 지우고 그 밑에 있는 # asyncio.run(run_extract()) 코드를 활성화 시켜서 돌려본다.
