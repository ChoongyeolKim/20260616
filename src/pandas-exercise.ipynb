# %%
# !python -m pip install pandas

# %%
import pandas as pd

# %%
s = pd.Series([100, 50, 30, 10])
s
# Out:
# 0    100
# 1     50
# 2     30
# 3     10
# dtype: int64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
s.index=['A', 'B', 'O', 'AB']
s
# Out:
# A     100
# B      50
# O      30
# AB     10
# dtype: int64

# %%
family = [
    ['김철수', 45, '남', 175, 'A'],
    ['이영희', 43, '여', 168, 'B'],
    ['김선우', 13, '남', 160, 'A'],
    ['김지우', 10, '여', 140, 'O'],
    ['김현우', 7, '남', 125, 'AB']
]

df = pd.DataFrame(family)
df.index = ['아빠','엄마','첫째','둘째','셋째']
df
# Out:
#       0   1  2    3   4
# 아빠  김철수  45  남  175   A
# 엄마  이영희  43  여  168   B
# 첫째  김선우  13  남  160   A
# 둘째  김지우  10  여  140   O
# 셋째  김현우   7  남  125  AB

# %%
df.columns = ['이름', '나이', '성별', '키', '혈액형']
df
# Out:
#      이름  나이 성별    키 혈액형
# 아빠  김철수  45  남  175   A
# 엄마  이영희  43  여  168   B
# 첫째  김선우  13  남  160   A
# 둘째  김지우  10  여  140   O
# 셋째  김현우   7  남  125  AB

# %%
df2 = df.set_index('이름')
df2
# Out:
#      나이 성별    키 혈액형
# 이름
# 김철수  45  남  175   A
# 이영희  43  여  168   B
# 김선우  13  남  160   A
# 김지우  10  여  140   O
# 김현우   7  남  125  AB

# %%
df.set_index('이름', inplace=True)

# %%
df
# Out:
#      나이 성별    키 혈액형
# 이름
# 김철수  45  남  175   A
# 이영희  43  여  168   B
# 김선우  13  남  160   A
# 김지우  10  여  140   O
# 김현우   7  남  125  AB

# %%
df = pd.read_csv('../data/scores.csv', encoding='cp949')
df
# Out:
#      학번      이름 성별     국어   영어     수학
# 0  2201    kate  f  100.0   90   95.0
# 1  2202  olivia  f   90.0   80   75.0
# 2  2203    emma  f   95.0  100  100.0
# 3  2204  sophia  f  100.0  100  100.0
# 4  2205     amy  f    NaN   35   60.0
# 5  2206   james  m   70.0   75   65.0
# 6  2207  daniel  m   80.0   90   55.0
# 7  2208   peter  m   50.0   60    NaN
# 8  2209   kevin  m  100.0  100   90.0
# 9  2210    jack  m   90.0   95   70.0

# %%
df.set_index('학번', inplace=True)
df
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2207  daniel  m   80.0   90   55.0
# 2208   peter  m   50.0   60    NaN
# 2209   kevin  m  100.0  100   90.0
# 2210    jack  m   90.0   95   70.0

# %%
df.head(3)
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0

# %%
df.tail(3)
# Out:
#          이름 성별     국어   영어    수학
# 학번
# 2208  peter  m   50.0   60   NaN
# 2209  kevin  m  100.0  100  90.0
# 2210   jack  m   90.0   95  70.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 2201 to 2210
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      10 non-null     str
#  1   성별      10 non-null     str
#  2   국어      9 non-null      float64
#  3   영어      10 non-null     int64
#  4   수학      9 non-null      float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 532.0 bytes

# %%
df.describe()
# Out:
#                국어          영어          수학
# count    9.000000   10.000000    9.000000
# mean    86.111111   82.500000   78.888889
# std     16.914819   21.114766   17.638342
# min     50.000000   35.000000   55.000000
# 25%     80.000000   76.250000   65.000000
# 50%     90.000000   90.000000   75.000000
# 75%    100.000000   98.750000   95.000000
# max    100.000000  100.000000  100.000000

# %%
df.dtypes
# Out:
# 이름        str
# 성별        str
# 국어    float64
# 영어      int64
# 수학    float64
# dtype: object

# %%
df['영어'].var()
# Out:
# np.float64(445.8333333333333)

# %%
df.value_counts('국어')
# Out:
# 국어
# 100.0    3
# 90.0     2
# 95.0     1
# 70.0     1
# 80.0     1
# 50.0     1
# Name: count, dtype: int64

# %%
df.sort_index()

# %%
df.sort_values('영어', ascending=False)
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2204  sophia  f  100.0  100  100.0
# 2203    emma  f   95.0  100  100.0
# 2209   kevin  m  100.0  100   90.0
# 2210    jack  m   90.0   95   70.0
# 2207  daniel  m   80.0   90   55.0
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2206   james  m   70.0   75   65.0
# 2208   peter  m   50.0   60    NaN
# 2205     amy  f    NaN   35   60.0

# %%
print(type(df['이름']))
df['이름']
# Out:
# <class 'pandas.Series'>
# 학번
# 2201      kate
# 2202    olivia
# 2203      emma
# 2204    sophia
# 2205       amy
# 2206     james
# 2207    daniel
# 2208     peter
# 2209     kevin
# 2210      jack
# Name: 이름, dtype: str

# %%
print(type(df[['이름']]))
df[['이름']]
# Out:
# <class 'pandas.DataFrame'>
#           이름
# 학번
# 2201    kate
# 2202  olivia
# 2203    emma
# 2204  sophia
# 2205     amy
# 2206   james
# 2207  daniel
# 2208   peter
# 2209   kevin
# 2210    jack

# %%
print(type(df.loc[2201]))
df.loc[2201]
# Out:
# <class 'pandas.Series'>
# 이름     kate
# 성별        f
# 국어    100.0
# 영어       90
# 수학     95.0
# Name: 2201, dtype: object

# %%
df.loc[[2201]]
# Out:
#         이름 성별     국어  영어    수학
# 학번
# 2201  kate  f  100.0  90  95.0

# %%
df.loc[[2201, 2205]]
# Out:
#         이름 성별     국어  영어    수학
# 학번
# 2201  kate  f  100.0  90  95.0
# 2205   amy  f    NaN  35  60.0

# %%
df.loc[2203]
# Out:
# 이름     emma
# 성별        f
# 국어     95.0
# 영어      100
# 수학    100.0
# Name: 2203, dtype: object

# %%
df.loc[2203, ['국어', '영어', '수학']]
# Out:
# 국어     95.0
# 영어    100.0
# 수학    100.0
# Name: 2203, dtype: float64

# %%
df.loc[[2201, 2205], '이름']
# Out:
# 학번
# 2201    kate
# 2205     amy
# Name: 이름, dtype: str

# %%
df.loc[[2201, 2205], ['이름', '수학']]
# Out:
#         이름    수학
# 학번
# 2201  kate  95.0
# 2205   amy  60.0

# %%
df.loc[[2201, 2205], ['국어', '영어', '수학']]
# Out:
#          국어  영어    수학
# 학번
# 2201  100.0  90  95.0
# 2205    NaN  35  60.0

# %%
df.loc[2201:2203, '국어']
# Out:
# 학번
# 2201    100.0
# 2202     90.0
# 2203     95.0
# Name: 국어, dtype: float64

# %%
df.iloc[0]
# Out:
# 이름     kate
# 성별        f
# 국어    100.0
# 영어       90
# 수학     95.0
# Name: 2201, dtype: object

# %%
df.iloc[:, [1, 2, 4]]
# Out:
#      성별     국어     수학
# 학번
# 2201  f  100.0   95.0
# 2202  f   90.0   75.0
# 2203  f   95.0  100.0
# 2204  f  100.0  100.0
# 2205  f    NaN   60.0
# 2206  m   70.0   65.0
# 2207  m   80.0   55.0
# 2208  m   50.0    NaN
# 2209  m  100.0   90.0
# 2210  m   90.0   70.0

# %%
df.loc[df['국어'] == 100]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2204  sophia  f  100.0  100  100.0
# 2209   kevin  m  100.0  100   90.0

# %%
scores = df.copy()
scores
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2207  daniel  m   80.0   90   55.0
# 2208   peter  m   50.0   60    NaN
# 2209   kevin  m  100.0  100   90.0
# 2210    jack  m   90.0   95   70.0

# %%
ko = scores['국어'] == 100
en = scores['영어'] == 100
ma = scores['수학'] == 100
scores.loc[(ko) & (en) & (ma)]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2204  sophia  f  100.0  100  100.0

# %%
scores.loc[(ko) | (en) | (ma)]
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2209   kevin  m  100.0  100   90.0

# %%
scores['평균'] = round((scores['국어']+scores['영어']+scores['수학']) / 3, 1)

# %%
scores
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores.drop(columns=['평균'])
# Out:
#           이름 성별     국어   영어     수학
# 학번
# 2201    kate  f  100.0   90   95.0
# 2202  olivia  f   90.0   80   75.0
# 2203    emma  f   95.0  100  100.0
# 2204  sophia  f  100.0  100  100.0
# 2205     amy  f    NaN   35   60.0
# 2206   james  m   70.0   75   65.0
# 2207  daniel  m   80.0   90   55.0
# 2208   peter  m   50.0   60    NaN
# 2209   kevin  m  100.0  100   90.0
# 2210    jack  m   90.0   95   70.0

# %%
scores
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores.drop(columns=['평균'], inplace=True)

# %%
scores.isnull()
# Out:
#          이름     성별     국어     영어     수학     평균
# 학번
# 2201  False  False  False  False  False  False
# 2202  False  False  False  False  False  False
# 2203  False  False  False  False  False  False
# 2204  False  False  False  False  False  False
# 2205  False  False   True  False  False   True
# 2206  False  False  False  False  False  False
# 2207  False  False  False  False  False  False
# 2208  False  False  False  False   True   True
# 2209  False  False  False  False  False  False
# 2210  False  False  False  False  False  False

# %%
scores.isnull().sum()
# Out:
# 이름    0
# 성별    0
# 국어    1
# 영어    0
# 수학    1
# 평균    2
# dtype: int64

# %%
scores.dropna()
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores.fillna(50)
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f   50.0   35   60.0   50.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   50.0   50.0
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores.fillna({'국어':70, '수학':50})
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f   70.0   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   50.0    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
temp2 = scores.fillna({'국어':70, '수학':50})
temp2
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f   70.0   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   50.0    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
temp2['평균'] = round((temp2['국어']+temp2['영어']+temp2['수학']) / 3, 1)
temp2
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f   70.0   35   60.0   55.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   50.0   53.3
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f    NaN   35   60.0    NaN
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60    NaN    NaN
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores.ffill()
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f  100.0   35   60.0  100.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   55.0   75.0
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores.bfill()
# Out:
#           이름 성별     국어   영어     수학     평균
# 학번
# 2201    kate  f  100.0   90   95.0   95.0
# 2202  olivia  f   90.0   80   75.0   81.7
# 2203    emma  f   95.0  100  100.0   98.3
# 2204  sophia  f  100.0  100  100.0  100.0
# 2205     amy  f   70.0   35   60.0   70.0
# 2206   james  m   70.0   75   65.0   70.0
# 2207  daniel  m   80.0   90   55.0   75.0
# 2208   peter  m   50.0   60   90.0   96.7
# 2209   kevin  m  100.0  100   90.0   96.7
# 2210    jack  m   90.0   95   70.0   85.0

# %%
scores.bfill().astype({'국어':'int64'})
# Out:
#           이름 성별   국어   영어     수학     평균
# 학번
# 2201    kate  f  100   90   95.0   95.0
# 2202  olivia  f   90   80   75.0   81.7
# 2203    emma  f   95  100  100.0   98.3
# 2204  sophia  f  100  100  100.0  100.0
# 2205     amy  f   70   35   60.0   70.0
# 2206   james  m   70   75   65.0   70.0
# 2207  daniel  m   80   90   55.0   75.0
# 2208   peter  m   50   60   90.0   96.7
# 2209   kevin  m  100  100   90.0   96.7
# 2210    jack  m   90   95   70.0   85.0

# %%
# !python -m pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='Malgun Gothic') # 'Apple Gothic'
plt.rc('axes', unicode_minus=False)

# %%
pd.Series([-1, 2, 3]).plot(title='테스트', figsize=(3, 2))
pass

# %%
df.plot(kind='bar', y='국어', figsize=(4, 3), color='red', title='국어점수')
pass

# %%
family = [
    ['김철수', 45, '남', 175, 'A'],
    ['이영희', 43, '여', 168, 'B'],
    ['김선우', 13, '남', 160, 'A'],
    ['김지우', 10, '여', 140, 'O'],
    ['김현우', 7, '남', 125, 'AB']
]

df = pd.DataFrame(family)
df.index = ['아빠','엄마','첫째','둘째','셋째']
df.columns = ['이름', '나이', '성별', '키', '혈액형']
df

# %%
family3 = [
    ['김철수', 45, '남', 175, 'A'],
    ['이영희', 43, '여', 168, 'B']
]

df3 = pd.DataFrame(family3)
df3.columns = ['이름', '나이', '성별', '키', '혈액형']
df3
# Out:
#     이름  나이 성별    키 혈액형
# 0  김철수  45  남  175   A
# 1  이영희  43  여  168   B

# %%
family4 = [
    ['김선우', 13, '남', 160],
    ['김지우', 10, '여', 140],
]

df4 = pd.DataFrame(family4)
df4.columns = ['이름', '나이', '성별', '키']
df4
# Out:
#     이름  나이 성별    키
# 0  김선우  13  남  160
# 1  김지우  10  여  140

# %%
pd.concat([df3, df4])
# Out:
#     이름  나이 성별    키  혈액형
# 0  김철수  45  남  175    A
# 1  이영희  43  여  168    B
# 0  김선우  13  남  160  NaN
# 1  김지우  10  여  140  NaN

# %%
family5 = [
    ['김선우', 13, '남', 160, 'A', 'TV'],
    ['김지우', 10, '여', 140, 'O', '유튜브'],
]

df5 = pd.DataFrame(family5)
df5.columns = ['이름', '나이', '성별', '키', '혈액형', '취미']
df5
# Out:
#     이름  나이 성별    키 혈액형   취미
# 0  김선우  13  남  160   A   TV
# 1  김지우  10  여  140   O  유튜브

# %%
pd.concat([df3, df5])
# Out:
#     이름  나이 성별    키 혈액형   취미
# 0  김철수  45  남  175   A  NaN
# 1  이영희  43  여  168   B  NaN
# 0  김선우  13  남  160   A   TV
# 1  김지우  10  여  140   O  유튜브

# %%
family6 = [
    ['남', 175],
    ['여', 168]
]

df6 = pd.DataFrame(family6)
df6.columns = ['성별', '키']
df6
# Out:
#   성별    키
# 0  남  175
# 1  여  168

# %%
family7 = [
    ['김철수', 45],
    ['이영희', 43]
]

df7 = pd.DataFrame(family7)
df7.columns = ['이름', '나이']
df7
# Out:
#     이름  나이
# 0  김철수  45
# 1  이영희  43

# %%
pd.concat([df6, df7], axis=1)
# Out:
#   성별    키   이름  나이
# 0  남  175  김철수  45
# 1  여  168  이영희  43

# %%
family8 = [
    ['남', 175, 'A'],
    ['여', 168, 'B'],
    ['남', 160, 'A'],
]

df8 = pd.DataFrame(family8)
df8.columns = ['성별', '키', '혈액형']
df8
# Out:
#   성별    키 혈액형
# 0  남  175   A
# 1  여  168   B
# 2  남  160   A

# %%
pd.concat([df8, df7], axis=1)
# Out:
#   성별    키 혈액형   이름    나이
# 0  남  175   A  김철수  45.0
# 1  여  168   B  이영희  43.0
# 2  남  160   A  NaN   NaN

# %%
family9 = [
    ['김철수', 45],
    ['이영희', 43],
    ['김선우', 13]
]

df9 = pd.DataFrame(family9)
df9.columns = ['이름', '나이']
df9
# Out:
#     이름  나이
# 0  김철수  45
# 1  이영희  43
# 2  김선우  13

# %%
family10 = [
    ['김철수', '남', 175],
    ['이영희', '여', 168],
    ['김지우', '여', 140]
]

df10 = pd.DataFrame(family10)
df10.columns = ['이름', '성별', '키']
df10
# Out:
#     이름 성별    키
# 0  김철수  남  175
# 1  이영희  여  168
# 2  김지우  여  140

# %%
pd.merge(df9, df10, on='이름')
# Out:
#     이름  나이 성별    키
# 0  김철수  45  남  175
# 1  이영희  43  여  168
